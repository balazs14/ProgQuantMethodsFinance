# %% [markdown]
# ### Task1: Cleaning up a fund name
#
# An analyst pasted a messy fund name into a variable:
#
# ```
# raw_name = "  danube VALUE fund  "
# ```
#
# Write code that, using as few lines as possible:
# 1. Removes the leading and trailing spaces.
# 2. Prints the cleaned fund name in Title Case.
# 3. Prints the length of the cleaned (stripped) name.

# %%
# %reset -f

# %% [markdown]
# ### Task 2: Formatting a bond coupon
#
# A bond is described by:
#
# ```
# bond_name = "Danube Treasury 2031"
# coupon_rate = 0.0453
# ```
#
# `coupon_rate` is stored as a decimal (i.e. 0.0453 means 4.53%). Print a single line reading exactly (obviously -- needs to work for any input):
#
# ```
# Bond: Danube Treasury 2031, Coupon: 4.53%
# ```
#
# with the coupon shown as a percentage to two decimal places. Be careful to print exactly as specified, including spaces.

# %%
# %reset -f
