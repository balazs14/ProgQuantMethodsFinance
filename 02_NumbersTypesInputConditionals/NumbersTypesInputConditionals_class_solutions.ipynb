# %% [markdown]
# # Numeric Types, Type Conversion, Boolean Type, Input, and Conditional Statements: Solutions
# This notebook is built from the Week 2 English HTML materials. Follow-along examples are paired with short explanations, and the review exercises are included unsolved.

# %% [markdown]
# ## Follow-along 1: Built-in numeric types
# Python provides `int`, `float`, and `complex` numeric types. Assign one value of each type and inspect them with `type()`.

# %%
# %reset -f
a = 1  # int
b = 3.14  # float
c = 1 + 1j  # complex

print(type(a))
print(type(b))
print(type(c))

# %% [markdown]
# ## Follow-along 2: Large integers
# Integers can be very large. Use exponentiation to create and display a large integer.

# %%
# %reset -f
long_number = 6 * 10 ** 23 + 1
print(long_number)

# %% [markdown]
# ## Follow-along 3: Even larger integers
# Python integers are not limited to ordinary machine-sized values, so the same expression can use a much larger exponent.

# %%
# %reset -f
very_long_number = 6 * 10 ** 230 + 1
print(very_long_number)

# %% [markdown]
# ## Follow-along 4: Floating-point literals
# A decimal point or scientific notation creates a `float`, even when the scientific-notation value is mathematically a whole number.

# %%
# %reset -f
f1 = 1.0
f2 = 6e23
f3 = 6E23

print(type(f1))
print(type(f2))
print(type(f3))

# %% [markdown]
# ## Follow-along 5: Floating-point representation
# Floating-point values are stored in binary, so formatting many decimal places can reveal representation error.

# %%
# %reset -f
x = 1 / 10
print(x)
s = format(x, ".30f")
print(s)

# %% [markdown]
# ## Follow-along 6: Numeric operation result types
# Addition and subtraction combine numeric types, while ordinary division produces a `float`.

# %%
# %reset -f
a = 1
b = 2
c = 3.0

print(type(a + b))
print(type(a / b))
print(type(a - c))

# %% [markdown]
# ## Follow-along 7: Exponentiation and modulo
# The `**` operator calculates powers and `%` returns the remainder after division.

# %%
# %reset -f
print(3 ** 2)
print(10 % 3)

# %% [markdown]
# ## Follow-along 8: Converting text to numeric types
# Use `float()` and `int()` to convert a string to a floating-point number and then to an integer.

# %%
# %reset -f
s = "3.14"
f = float(s)  # converting text to a floating-point number
i = int(f)  # converting a floating-point number to an integer

print(type(s), s)
print(type(f), f)
print(type(i), i)

# %% [markdown]
# ## Follow-along 9: A conversion that fails
# A decimal string cannot be passed directly to `int()`, so this example demonstrates the resulting `ValueError`.

# %%
# %reset -f
s = "3.14"
i = int(s)

# %% [markdown]
# ## Follow-along 10: Converting numbers to text
# `str()` converts numbers to text. Numeric addition and string concatenation then produce different results.

# %%
# %reset -f
i1 = 5
i2 = 10
s1 = str(i1)
s2 = str(i2)

print(i1 + i2)
print(s1 + s2)

# %% [markdown]
# ## Follow-along 11: Boolean values and comparisons
# Boolean values are `True` or `False`. Comparison operators such as `==`, `!=`, `<`, and `>=` produce boolean results.

# %%
# %reset -f
a, b = 10, 15

x = a > b
y = a > 0 and a < 100
z = x or y

print(x)
print(y)
print(z)

# %% [markdown]
# ## Follow-along 12: Reading text input
# `input()` displays a prompt, waits for the user to press Enter, and stores the entered text in a variable.

# %%
# %reset -f
message = input("Say something and I will repeat it: ")
print(message)

# %% [markdown]
# ## Follow-along 13: Input is text by default
# Even numeric-looking input is initially a string, so attempting arithmetic before conversion raises a `TypeError`.

# %%
# %reset -f
x = input("Give me a number and I will tell you its square: ")
print(x ** 2)

# %% [markdown]
# ## Follow-along 14: Converting input before arithmetic
# Convert the input to `int` before calculating its square.

# %%
# %reset -f
x = input("Give me a number and I will tell you its square: ")
x = int(x)
print(x ** 2)

# %% [markdown]
# ## Follow-along 15: A basic `if` statement
# The indented block runs only when the condition after `if` is true.

# %%
# %reset -f
a = 7
b = 13
if b > a:
    print("b is greater than a")

# %% [markdown]
# ## Follow-along 16: The one-line form of `if`
# When the branch has only one instruction, Python also permits the instruction on the same line.

# %%
# %reset -f
a, b = 7, 13  # this can be shortened here too
if b > a: print("b is greater than a")

# %% [markdown]
# ## Follow-along 17: The `else` branch
# Use `else` to run a different indented block when the `if` condition is false.

# %%
# %reset -f
a, b = 17, 13
if b > a:
    print("b is greater than a")
else:
    print("b is less than or equal to a")

# %% [markdown]
# ## Follow-along 18: Nested conditions
# A second `if` can be nested inside the `else` branch to handle a third possibility.

# %%
# %reset -f
a, b = 13, 13
if b > a:
    print("b is greater than a")
else:
    if b == a:
        print("b is equal to a")
    else:
        print("b is less than a")

# %% [markdown]
# ## Follow-along 19: The `elif` form
# `elif` expresses the middle branch more compactly than nesting a second `if` inside `else`.

# %%
# %reset -f
a, b = 13, 13
if b > a:
    print("b is greater than a")
elif b == a:
    print("b is equal to a")
else:
    print("b is less than a")

# %% [markdown]
# ## Follow-along 20: The `pass` statement
# Use `pass` as a temporary placeholder when a conditional branch is intentionally empty during development.

# %%
# %reset -f
a, b = 17, 13
if b > a:
    pass
else:
    print("b is less than or equal to a")

# %% [markdown]
# ## Follow-along 21: Checking converted input
# Convert valid numeric input and calculate its square. This version does not yet handle invalid input.

# %%
# %reset -f
x = input("Give me a number and I will tell you its square: ")
x = int(x)
print(x ** 2)

# %% [markdown]
# ## Follow-along 22: Validating numeric input
# `isnumeric()` checks whether the input text contains a numeric value before converting it. The invalid-input message uses `\n` for a line break.

# %%
# %reset -f
x = input("Give me a number and I will tell you its square: ")
if x.isnumeric():
    x = int(x)
    print(x ** 2)
else:
    print("Invalid input!\nOnly a numeric value may be given.")

# %% [markdown]
# # Review exercises: Numeric types
# Write a program that calculates how much 20 thousand HUF is worth in euros and dollars, using rates of 352.5 HUF per euro and 295.5 HUF per dollar, variables, and whole-number results.

# %%
# %reset -f
huf = 20000
euro_rate = 352.5
dollar_rate = 295.5
euros = huf / euro_rate
dollars = huf / dollar_rate
print(f"Euros: {euros:.0f}")
print(f"Dollars: {dollars:.0f}")

# %% [markdown]
# ## Numeric exercise 2
# Solve `ax+b=0` for `a=3` and `b=1`, and display the solution to two decimal places as `The solution of the equation: {value}`.

# %%
# %reset -f
a = 3
b = 1
solution = -b / a
print(f"The solution of the equation: {solution:.2f}")

# %% [markdown]
# ## Numeric exercise 3
# Calculate the volume and surface area of a cuboid with edges `a=3`, `b=4`, and `c=5`, using `V=abc` and `A=2(ab+ac+bc)`, and show the answer attractively on one line.

# %%
# %reset -f
a = 3
b = 4
c = 5
volume = a * b * c
surface = 2 * (a * b + a * c + b * c)
print(f"Volume: {volume}, Surface area: {surface}")

# %% [markdown]
# ## Numeric exercise 4
# Calculate the circumference of a circle with radius 8 and format it to two decimal places.

# %%
# %reset -f
radius = 8
circumference = 2 * 3.14 * radius
print(f"Circumference: {circumference:.2f}")

# %% [markdown]
# ## Numeric exercise 5
# Calculate the tenth power of 9.

# %%
# %reset -f
print(9 ** 10)

# %% [markdown]
# ## Numeric exercise 6
# Calculate the remainder of the division of two given numbers.

# %%
# %reset -f
first = 17
second = 5
print(first % second)

# %% [markdown]
# ## Numeric exercise 7
# Calculate the integer-division result of two given numbers.

# %%
# %reset -f
first = 17
second = 5
print(first // second)

# %% [markdown]
# ## Numeric exercise 8
# Calculate the hypotenuse of a right-angled triangle from its two legs. Use the exponentiation operator.

# %%
# %reset -f
first_leg = 3
second_leg = 4
hypotenuse = (first_leg ** 2 + second_leg ** 2) ** 0.5
print(hypotenuse)

# %% [markdown]
# # Review exercises: Boolean type
# Ask for two values and check whether they are equal.

# %%
# %reset -f
first = input("First value: ")
second = input("Second value: ")
print(first == second)

# %% [markdown]
# ## Boolean exercise 2
# Ask for three strings and report whether all three are the same or whether any two are the same, using compound boolean expressions.

# %%
# %reset -f
first = input("First string: ")
second = input("Second string: ")
third = input("Third string: ")
all_same = first == second and second == third
any_pair_same = first == second or first == third or second == third
print(f"All three are the same: {all_same}")
print(f"At least two are the same: {any_pair_same}")

# %% [markdown]
# ## Boolean exercise 3
# Determine the values of `not(True and True)`, `True or False`, `not(False and True)`, and `False and False`.

# %%
# %reset -f
print(not (True and True))
print(True or False)
print(not (False and True))
print(False and False)

# %% [markdown]
# ## Boolean exercise 4
# Ask for a year and print whether it is a leap year. Check that it is numeric and four characters long, using a compound boolean expression.

# %%
# %reset -f
year_text = input("Year: ")
if year_text.isnumeric() and len(year_text) == 4:
    year = int(year_text)
    leap = year % 400 == 0 or (year % 4 == 0 and year % 100 != 0)
    print(leap)
else:
    print("Invalid year")

# %% [markdown]
# ## Boolean exercise 5
# Implement exclusive OR using two two-way stairwell light-switch positions. Accept only two chosen values, request invalid values again, and report whether the light is on.

# %%
# %reset -f
first = input("First switch position (0 or 1): ")
second = input("Second switch position (0 or 1): ")
valid = (first == "0" or first == "1") and (second == "0" or second == "1")
if valid:
    print(first != second)
else:
    print("Invalid switch position")

# %% [markdown]
# # Review exercises: Input
# Ask for the user's name and greet them by their full name.

# %%
# %reset -f
name = input("Full name: ")
space = name.find(" ")
first_name = name[:space]
print(f"Hello, {first_name}!")

# %% [markdown]
# ## Input exercise 2
# Ask for the user's name and greet them by their first name.

# %%
# %reset -f
name = input("Full name: ")
space = name.find(" ")
first_name = name[:space]
print(f"Hello, {first_name}!")

# %% [markdown]
# ## Input exercise 3
# Ask for the radius of a circle and print its area. You do not need to handle non-numeric input.

# %%
# %reset -f
radius = float(input("Radius: "))
area = 3.14 * radius ** 2
print(area)

# %% [markdown]
# ## Input exercise 4
# Ask for a floating-point number and print it converted to an integer.

# %%
# %reset -f
number = float(input("Floating-point number: "))
print(int(number))

# %% [markdown]
# ## Input exercise 5
# Ask for a string and print it reversed.

# %%
# %reset -f
text = input("Text: ")
print(text[::-1])

# %% [markdown]
# # Review exercises: Conditional statements
# Read a non-zero integer and print its sign: Positive or Negative.

# %%
# %reset -f
number = int(input("Non-zero integer: "))
if number > 0:
    print("Positive")
else:
    print("Negative")

# %% [markdown]
# ## Conditional exercise 2
# Read two different real numbers and print the larger one.

# %%
# %reset -f
first = float(input("First real number: "))
second = float(input("Second real number: "))
if first > second:
    print(first)
else:
    print(second)

# %% [markdown]
# ## Conditional exercise 3
# Read three integers and print the largest. The numbers are not necessarily different.

# %%
# %reset -f
first = int(input("First integer: "))
second = int(input("Second integer: "))
third = int(input("Third integer: "))
if first >= second and first >= third:
    print(first)
elif second >= first and second >= third:
    print(second)
else:
    print(third)

# %% [markdown]
# ## Conditional exercise 4
# Ask for a name and age. Under 20, greet informally by first name; over 20, greet formally by full name.

# %%
# %reset -f
name = input("Full name: ")
space = name.find(" ")
first_name = name[:space]
age = int(input("Age: "))
if age < 20:
    print(f"Hi, {first_name}!")
else:
    print(f"Good day, {name}!")

# %% [markdown]
# ## Conditional exercise 5
# Ask for a circle radius and print its area. If the value is not numeric, report an incorrect value.

# %%
# %reset -f
radius_text = input("Radius: ")
if radius_text.isnumeric():
    radius = float(radius_text)
    print(3.14 * radius ** 2)
else:
    print("Incorrect value")

# %% [markdown]
# ## Conditional exercise 6
# Ask for a number. If it can be converted, report whether it is zero, even, or odd; otherwise report an incorrect value.

# %%
# %reset -f
number_text = input("Number: ")
if number_text.isnumeric():
    number = int(number_text)
    if number == 0:
        print("Zero")
    elif number % 2 == 0:
        print("Even")
    else:
        print("Odd")
else:
    print("Incorrect value")

# %% [markdown]
# ## Conditional exercise 7
# Ask for a temperature and whether it is Celsius or Fahrenheit, then print the value on the opposite scale. Reject unsuitable input.

# %%
# %reset -f
temperature_text = input("Temperature: ")
scale = input("Scale (C/F): ")
if temperature_text.isnumeric() and (scale == "C" or scale == "F"):
    temperature = float(temperature_text)
    if scale == "C":
        print(temperature * 9 / 5 + 32)
    else:
        print((temperature - 32) * 5 / 9)
else:
    print("Unsuitable input")

# %% [markdown]
# ## Conditional exercise 8
# Ask for a string and check whether it is entirely lowercase.

# %%
# %reset -f
text = input("Text: ")
print(text == text.lower())

# %% [markdown]
# ## Conditional exercise 9
# Read an age and print Young for ages 0-39, Middle-aged for 40-64, or Old for ages 65 and above.

# %%
# %reset -f
age = int(input("Age: "))
if age <= 39:
    print("Young")
elif age <= 64:
    print("Middle-aged")
else:
    print("Old")
